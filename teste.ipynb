# %%
import pyautogui
import time

pos = pyautogui.locateOnScreen("logo.png", confidence=0.5)
print(pos)
# Out:
# Box(left=np.int64(0), top=np.int64(0), width=1919, height=130)

# %%
# pyautogui.hotkey('win', 'down')
# pyautogui.moveTo(pos)
# pyautogui.moveTo(pos.left+10, pos.top + 400)
