# %%
import pandas as pd

df = pd.read_excel(
    r'c:\Fator R\fATOR r - 323,326,327,805,1104,1105,1106.XLS',
    engine='xlrd'
).sort_values('geempre_nome_emp').reset_index(drop=True)
df
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'iso-8859-1'
#    geempre_codi_emp                  geempre_nome_emp  \
# 0               805              ASSV CONFECCOES LTDA
# 1              1105         BFV SERVICOS MEDICOS LTDA
# 2              1104         BSF SERVICOS MEDICOS LTDA
# 3               323    CASTILHO SERVICOS MEDICOS LTDA
# 4               327  MARCUS VINICIUS TAPPARO FIGUEIRA
# 5              1106         NFM SERVICOS MEDICOS LTDA
# 6               326     SANTANA SERVICOS MEDICOS LTDA
#
#                   geempre_razao_emp  geempre_tins_emp  geempre_cgce_emp  \
# 0              ASSV CONFECCOES LTDA                 1    58440605000183
# 1         BFV SERVICOS MEDICOS LTDA                 1    65252182000133
# 2         BSF SERVICOS MEDICOS LTDA                 1    61331422000134
# 3    CASTILHO SERVICOS MEDICOS LTDA                 1    46379667000148
# 4  MARCUS VINICIUS TAPPARO FIGUEIRA                 1    26751300000104
# ...

# %%
# Out:
# True
