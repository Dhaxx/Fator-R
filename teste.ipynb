# %%
import pandas as pd

df = pd.read_excel("C:\\Fator R\\Fator R - 1104, 1105, 1106.xls", engine='xlrd')

df.head()
# Out:
#    geempre_codi_emp           geempre_nome_emp          geempre_razao_emp  \
# 0              1104  BSF SERVICOS MEDICOS LTDA  BSF SERVICOS MEDICOS LTDA
# 1              1105  BFV SERVICOS MEDICOS LTDA  BFV SERVICOS MEDICOS LTDA
# 2              1106  NFM SERVICOS MEDICOS LTDA  NFM SERVICOS MEDICOS LTDA
#
#    geempre_tins_emp  geempre_cgce_emp datainicial  datafinal  \
# 0                 1    61331422000134  2025-12-01 2025-12-31
# 1                 1    65252182000133  2025-12-01 2025-12-31
# 2                 1    65220570000132  2025-12-01 2025-12-31
#
#    valor_faturamento_nfse  inss_mes_anterior  inss_teste  salario_minimo
# 0                 23762.9            1067.15           0            1621
# 1                 22966.8             892.62           0            1621
# 2                  8000.0             229.15           0            1621

# %%
lista_resultado = ((df["valor_faturamento_nfse"] * 0.28) - df["inss_mes_anterior"]).tolist()
print(lista_resultado)
# Out:
# [5586.462000000001, 5538.084000000001, 2010.85]
